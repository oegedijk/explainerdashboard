# %% [markdown]
# # Simple Classifier Dashboard example
#
# This notebook is derived from `dashboard_examples.ipynb`, to show how you may run a simpler classifier dashboard instead of the default one. Simple classifier/regression dashboard is rolled out with version 0.3.5 ([Release Note](https://github.com/oegedijk/explainerdashboard/releases/tag/v0.3.5)).
#
# * This notebook demostrates how the simplified version works for a `ClassifierExplainer`. If the underlying explainer object is an instance of `RegressionExplainer`, regression related metrics will be showed instead.

# %% [markdown]
# Uncomment to install explainerdashboard (>=0.3.5):

# %%
#!pip install explainerdashboard

# %% [markdown]
# ## Set notebook properties:

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Load classifier data:
#     - predicting probability that a person on the titanic survived

# %%
from explainerdashboard.datasets import titanic_survive, titanic_names

# %%
X_train, y_train, X_test, y_test = titanic_survive()
train_names, test_names = titanic_names()

# %%
X_train.head()
# Out:
#                              Fare    Age  PassengerClass  \
# Passenger
# Braund, Mr. Owen Harris    7.2500   22.0               3
# Heikkinen, Miss. Laina     7.9250   26.0               3
# Allen, Mr. William Henry   8.0500   35.0               3
# Moran, Mr. James           8.4583 -999.0               3
# McCarthy, Mr. Timothy J   51.8625   54.0               1
#
#                           No_of_siblings_plus_spouses_on_board  \
# Passenger
# Braund, Mr. Owen Harris                                      1
# Heikkinen, Miss. Laina                                       0
# Allen, Mr. William Henry                                     0
# Moran, Mr. James                                             0
# McCarthy, Mr. Timothy J                                      0
#
#                           No_of_parents_plus_children_on_board  Sex_female  \
# Passenger
# Braund, Mr. Owen Harris                                      0           0
# Heikkinen, Miss. Laina                                       0           1
# Allen, Mr. William Henry                                     0           0
# Moran, Mr. James                                             0           0
# McCarthy, Mr. Timothy J                                      0           0
#
#                           Sex_male  Sex_nan  Deck_A  Deck_B  ...  Deck_D  \
# Passenger                                                    ...
# Braund, Mr. Owen Harris          1        0       0       0  ...       0
# Heikkinen, Miss. Laina           0        0       0       0  ...       0
# Allen, Mr. William Henry         1        0       0       0  ...       0
# Moran, Mr. James                 1        0       0       0  ...       0
# McCarthy, Mr. Timothy J          1        0       0       0  ...       0
#
#                           Deck_E  Deck_F  Deck_G  Deck_T  Deck_Unkown  \
# Passenger
# Braund, Mr. Owen Harris        0       0       0       0            1
# Heikkinen, Miss. Laina         0       0       0       0            1
# Allen, Mr. William Henry       0       0       0       0            1
# Moran, Mr. James               0       0       0       0            1
# McCarthy, Mr. Timothy J        1       0       0       0            0
#
#                           Embarked_Cherbourg  Embarked_Queenstown  \
# Passenger
# Braund, Mr. Owen Harris                    0                    0
# Heikkinen, Miss. Laina                     0                    0
# Allen, Mr. William Henry                   0                    0
# Moran, Mr. James                           0                    1
# McCarthy, Mr. Timothy J                    0                    0
#
#                           Embarked_Southampton  Embarked_Unknown
# Passenger
# Braund, Mr. Owen Harris                      1                 0
# Heikkinen, Miss. Laina                       1                 0
# Allen, Mr. William Henry                     1                 0
# Moran, Mr. James                             0                 0
# McCarthy, Mr. Timothy J                      1                 0
#
# [5 rows x 21 columns]

# %% [markdown]
# We'll use the passenger names later as idxs for the Explainer, such that they get displayed on the contributions tab of the dashboard, and you can also use them to pass as an index into various methods:

# %%
train_names[:5]
# Out:
# ['Braund, Mr. Owen Harris',
#  'Heikkinen, Miss. Laina',
#  'Allen, Mr. William Henry',
#  'Moran, Mr. James',
#  'McCarthy, Mr. Timothy J']

# %% [markdown]
# ## Run with SimplifiedClassifierDashboard
# - This dashboard creates an explainer object out the model and the X and y that you wish to display.
# - The explainer object calculates shap values, permutation importances, pdp's, etc, and provides all kinds of plots that will be used by the ExplainerDashboard object
# - The new simplified classifier dashboard will display all of the followings on a single tab:
#     - Confusion matrix
#     - One other model quality indicator; default is ROC AUC curve, you may change it to other valid `classifier_components`. See details below.
#     - Shap importances
#     - Shap dependence
#     - index selector
#     - index prediction summary
#     - Shap contributions graph
# - Similarly, the new simplified regression dashboard will display all of the followings on a single tab:
#     - Goodness of fit
#     - One other model quality indicator; default is plot vs feature, you may change it to other valid `regression_components`, such as ['residuals', 'metrics'].
#     - Shap importances
#     - Shap dependence
#     - index selector
#     - index prediction summary
#     - Shap contributions graph

# %%
from sklearn.ensemble import RandomForestClassifier
from explainerdashboard import ClassifierExplainer, ExplainerDashboard

# %%
model = RandomForestClassifier(n_estimators=50, max_depth=5)
model.fit(X_train, y_train)

explainer = ClassifierExplainer(model, X_test, y_test)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=50)
# Detected RandomForestClassifier model: Changing class type to RandomForestClassifierExplainer...
# Note: model_output=='probability', so assuming that raw shap output of RandomForestClassifier is in probability space...
# Generating self.shap_explainer = shap.TreeExplainer(model)

# %% [markdown]
# Passing the argument `simple=True` to an ExplainerDashboard object will load the single page simplified classifier dashboard

# %%
db = ExplainerDashboard(explainer, simple=True)
# Out:
# Building ExplainerDashboard..
# Detected notebook environment, consider setting mode='external', mode='inline' or mode='jupyterlab' to keep the notebook interactive while the dashboard is running...
# Calculating shap values...
# Generating layout...
# Calculating dependencies...
# Calculating confusion matrices...
# Calculating prediction probabilities...
# Calculating pred_percentiles...
# Calculating roc auc curves...
# Calculating predictions...
# Calculating metrics...
# Reminder: you can store the explainer (including calculated dependencies) with explainer.dump('explainer.joblib') and reload with e.g. ClassifierExplainer.from_file('explainer.joblib')
# Registering callbacks...

# %% [markdown]
# Running the simplified classifier dashboard on port 9000:

# %%
db.run(port=9000)
# Out:
# Starting ExplainerDashboard on http://192.168.1.21:9000
# Dash is running on http://0.0.0.0:9000/
#
#  * Serving Flask app "explainerdashboard.dashboards" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:9000/ (Press CTRL+C to quit)
# 192.168.1.21 - - [07/May/2021 15:42:32] "GET / HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:32] "GET /assets/bootstrap.min.css?m=1620419845.4037383 HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:32] "GET /_dash-component-suites/dash_renderer/prop-types@15.v1_9_1m1618962237.7.2.min.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:32] "GET /_dash-component-suites/dash_renderer/react@16.v1_9_1m1618962237.14.0.min.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:32] "GET /_dash-component-suites/dash_renderer/react-dom@16.v1_9_1m1618962237.14.0.min.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:32] "GET /_dash-component-suites/dash_renderer/polyfill@7.v1_9_1m1618962237.8.7.min.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:32] "GET /_dash-component-suites/dash_core_components/dash_core_components.v1_16_0m1618962238.min.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:32] "GET /_dash-component-suites/dash_table/bundle.v4_11_3m1618962241.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:32] "GET /_dash-component-suites/dash_core_components/dash_core_components-shared.v1_16_0m1618962238.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:32] "GET /_dash-component-suites/dash_html_components/dash_html_components.v1_1_3m1618962240.min.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:32] "GET /_dash-component-suites/dash_bootstrap_components/_components/dash_bootstrap_components.v0_12_0m1618962292.min.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:32] "GET /_dash-component-suites/dash_renderer/dash_renderer.v1_9_1m1618962237.min.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:33] "GET /_dash-dependencies HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:33] "GET /_dash-layout HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:34] "GET /assets/favicon.ico?m=1620419845.4037383 HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:34] "GET /_dash-component-suites/dash_core_components/async-dropdown.v1_16_0m1617903285.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:34] "GET /_dash-component-suites/dash_core_components/async-graph.v1_16_0m1617903285.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:34] "GET /_dash-component-suites/dash_core_components/async-slider.v1_16_0m1617903285.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:34] "GET /_dash-component-suites/dash_core_components/async-plotlyjs.v1_16_0m1617903285.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:36] "POST /_dash-update-component HTTP/1.1" 204 -
# 192.168.1.21 - - [07/May/2021 15:42:36] "POST /_dash-update-component HTTP/1.1" 204 -
# 192.168.1.21 - - [07/May/2021 15:42:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:42:36] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
db.terminate(port=9000)

# %% [markdown]
# In addition to the `simple=True` argument, if you'd like to see plots other than the ROC AUC graph, you may pass the following valid arguments to `classifier_custom_component`: ['pr_auc', 'precision_graph', 'lift_curve', 'class_graph', 'roc_auc']. See an example below for generating [PrecisionComponent](https://explainerdashboard.readthedocs.io/en/latest/components.html#precisioncomponent).

# %%
db = ExplainerDashboard(explainer, simple=True, classifier_custom_component='precision_graph')
# Out:
# Building ExplainerDashboard..
# Detected notebook environment, consider setting mode='external', mode='inline' or mode='jupyterlab' to keep the notebook interactive while the dashboard is running...
# Generating layout...
# Calculating dependencies...
# Reminder: you can store the explainer (including calculated dependencies) with explainer.dump('explainer.joblib') and reload with e.g. ClassifierExplainer.from_file('explainer.joblib')
# Registering callbacks...

# %% [markdown]
# And run the dashboard on the default port (=8050):

# %%
db.run()
# Out:
# Starting ExplainerDashboard on http://192.168.1.21:8050
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
#
#  * Serving Flask app "explainerdashboard.dashboards" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:8050/ (Press CTRL+C to quit)
# 192.168.1.21 - - [07/May/2021 15:47:11] "GET / HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:12] "GET /assets/bootstrap.min.css?m=1620419845.4037383 HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:12] "GET /_dash-component-suites/dash_renderer/react@16.v1_9_1m1618962237.14.0.min.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:12] "GET /_dash-component-suites/dash_renderer/react-dom@16.v1_9_1m1618962237.14.0.min.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:12] "GET /_dash-component-suites/dash_renderer/polyfill@7.v1_9_1m1618962237.8.7.min.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:12] "GET /_dash-component-suites/dash_renderer/prop-types@15.v1_9_1m1618962237.7.2.min.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:12] "GET /_dash-component-suites/dash_core_components/dash_core_components.v1_16_0m1618962238.min.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:12] "GET /_dash-component-suites/dash_core_components/dash_core_components-shared.v1_16_0m1618962238.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:12] "GET /_dash-component-suites/dash_table/bundle.v4_11_3m1618962241.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:12] "GET /_dash-component-suites/dash_bootstrap_components/_components/dash_bootstrap_components.v0_12_0m1618962292.min.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:12] "GET /_dash-component-suites/dash_html_components/dash_html_components.v1_1_3m1618962240.min.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:12] "GET /_dash-component-suites/dash_renderer/dash_renderer.v1_9_1m1618962237.min.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:13] "GET /_dash-layout HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:13] "GET /_dash-dependencies HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:13] "GET /assets/favicon.ico?m=1620419845.4037383 HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:14] "GET /_dash-component-suites/dash_core_components/async-dropdown.v1_16_0m1617903285.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:14] "GET /_dash-component-suites/dash_core_components/async-graph.v1_16_0m1617903285.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:14] "GET /_dash-component-suites/dash_core_components/async-slider.v1_16_0m1617903285.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:14] "GET /_dash-component-suites/dash_core_components/async-plotlyjs.v1_16_0m1617903285.js HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:15] "POST /_dash-update-component HTTP/1.1" 204 -
# 192.168.1.21 - - [07/May/2021 15:47:15] "POST /_dash-update-component HTTP/1.1" 204 -
# 192.168.1.21 - - [07/May/2021 15:47:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.1.21 - - [07/May/2021 15:47:16] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
db.terminate()

# %% [markdown]
# mode='inline', 'jupyterlab', 'external' works as usual.
